# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("GIE2022-2S.csv")
df.head(2)
# Out:
#                     Marca temporal      Nombre de usuario  \
# 0  2022/08/13 12:34:10 a. m. GMT-5   jiuribeg@unal.edu.co
# 1  2022/08/13 12:37:02 a. m. GMT-5  vhurtados@unal.edu.co
#
#   ¿Qué carrera estudia?                      Universidad donde estudia:  \
# 0          Estadística                            Universidad Nacional
# 1           Estadística  Universidad Nacional de Colombia sede Medellín
#
#    ¿Cuántas matriculas lleva al momento? Escriba el número, en caso de ser egresado escriba 'Egresado'  \
# 0                                                  6
# 1                                                  8
#
#   Número de horas de estudio que dedica semanalmente:  ¿Qué edad tiene?  \
# 0                                                 30                 19
# 1                                                 50                 21
#
#   ¿Ha tenido acercamientos a la programación? ¿Qué lenguaje(s) ha trabajado?  \
# ...

# %%
df['¿Qué día de la semana tiene disponibilidad para reuniones del GIE? (Puede seleccionar varios)']
# Out:
# 0           Lunes;Viernes
# 1     Lunes;Martes;Sábado
# 2                   Lunes
# 3            Lunes;Sábado
# 4           Lunes;Viernes
# 5     Lunes;Martes;Jueves
# 6            Lunes;Sábado
# 7            Lunes;Sábado
# 8            Lunes;Sábado
# 9                   Lunes
# 10              Miércoles
# 11          Lunes;Viernes
# Name: ¿Qué día de la semana tiene disponibilidad para reuniones del GIE? (Puede seleccionar varios), dtype: object

# %%
df['¿En qué intervalo de tiempo? (Puede seleccionar varias)']
# Out:
# 0                                         4:00pm-6:00pm
# 1                          10:00am-12:00m;4:00pm-6:00pm
# 2            10:00am-12:00m;2:00pm-4:00pm;4:00pm-6:00pm
# 3                                           Todo el día
# 4            10:00am-12:00m;2:00pm-4:00pm;4:00pm-6:00pm
# 5           8:00am-10:00am;10:00am-12:00m;2:00pm-4:00pm
# 6     6:00am-8:00am;8:00am-10:00am;10:00am-12:00m;4:...
# 7                         8:00am-10:00am;10:00am-12:00m
# 8     6:00am-8:00am;8:00am-10:00am;10:00am-12:00m;2:...
# 9                                         4:00pm-6:00pm
# 10                                       10:00am-12:00m
# 11                          2:00pm-4:00pm;4:00pm-6:00pm
# Name: ¿En qué intervalo de tiempo? (Puede seleccionar varias), dtype: object

# %%
df['¿Qué día de la semana tiene disponibilidad para reuniones del GIE? (Puede seleccionar varios)'].str.split(';')
# Out:
# 0            [Lunes, Viernes]
# 1     [Lunes, Martes, Sábado]
# 2                     [Lunes]
# 3             [Lunes, Sábado]
# 4            [Lunes, Viernes]
# 5     [Lunes, Martes, Jueves]
# 6             [Lunes, Sábado]
# 7             [Lunes, Sábado]
# 8             [Lunes, Sábado]
# 9                     [Lunes]
# 10                [Miércoles]
# 11           [Lunes, Viernes]
# Name: ¿Qué día de la semana tiene disponibilidad para reuniones del GIE? (Puede seleccionar varios), dtype: object

# %%
df['¿Qué día de la semana tiene disponibilidad para reuniones del GIE? (Puede seleccionar varios)'].str.split(';').explode('var1').value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['¿En qué intervalo de tiempo? (Puede seleccionar varias)'].str.split(';').explode('var1').value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
a = [1, 2 , 4]
for i in a:
    print(i)

#a. [1, 2 , 3, 1, 2, 3]
#b. [1, 2, 3, 1, 4, 9]
#c. [1, 4, 9]
#d. None above
# Out:
# 1
# 2
# 4

# %%
df['Mencione uno o varios temas de interés propio para investigar:']
# Out:
# 0              Educación, economía, ciudad, psicología
# 1      Epidemiología, medicina, Inteligencia artificial
# 2                                       Salud y deporte
# 3     publicación de resultados, manejo de estructur...
# 4                       Actuaría, salud y epidemiología
# 5                      Salud Mental, gobierno de datos.
# 6                Temas de salud pública o enfermedades
# 7     Reconocimiento de patrones en imágenes o recom...
# 8     Investigación y comparación de métodos estadís...
# 9     Me interesa la ingeniería de datos y todo lo q...
# 10                                 Analisis de mercado
# 11                       Cambio climático, sector salud
# Name: Mencione uno o varios temas de interés propio para investigar:, dtype: object

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS

# %%
text = " ".join(i for i in df['Mencione uno o varios temas de interés propio para investigar:'])
stopwords = set(['de', 'datos', 'y', 'que', 'para', 'o', 'la'])
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
text = " ".join(i for i in df['Escriba qué expectativas tiene con el GIE, qué motivaciones tiene y qué cosas considera que podrían ser un problema para lograr ese objetivo.'])
stopwords = set(['de', 'datos', 'y', 'que', 'para', 'o', 'la', 'el', 'un', 'lo', 'a', 'me', 'en', 'mi', 'con'])
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
text = " ".join(i for i in df['¿Tiene algún hobby? Escriba cuál o cuáles'])
stopwords = set(['de', 'datos', 'y', 'que', 'para', 'o', 'la', 'el', 'un', 'lo', 'a', 'me', 'en', 'mi', 'con'])
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
